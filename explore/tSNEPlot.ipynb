# %%
from FlowCytometryTools import FCMeasurement, ThresholdGate
# import os, FlowCytometryTools
from pylab import *

# # Locate sample data included with this package
# datadir = os.path.join(FlowCytometryTools.__path__[0], 'tests', 'data', 'Plate01')
# datafile = os.path.join(datadir, 'RFP_Well_A3.fcs')

datafile = '/Users/Kitty/temp/fcs/2016-05-26_PANEL 2_ZF_panel 2_F1636737_020.fcs' 

# Load data
tsample = FCMeasurement(ID='Test Sample', datafile=datafile)
print tsample.channels
tsample = tsample.transform('hlog', channels=['FSC-A', 'SSC-H'], b=500.0)
type(tsample)
# Plot
tsample.plot(['FSC-A', 'SSC-H'], kind='scatter', alpha=0.6, color='gray');
grid(True)

show() # <-- Uncomment when running as a script.
# Out:
#                       $PnN  $PnB  $PnG    $PnE    $PnR  $PnV
# Channel Number
# 1                    FSC-A    32   1.0  [0, 0]  262144   310
# 2                    FSC-H    32   1.0  [0, 0]  262144   310
# 3                    FSC-W    32   1.0  [0, 0]  262144   310
# 4                    SSC-A    32   1.0  [0, 0]  262144   286
# 5                    SSC-H    32   1.0  [0, 0]  262144   286
# 6                    SSC-W    32   1.0  [0, 0]  262144   286
# 7                  BB515-A    32   1.0  [0, 0]  262144   457
# 8                     PE-A    32   1.0  [0, 0]  262144   573
# 9               PE-CF594-A    32   1.0  [0, 0]  262144   541
# 10                PE-Cy7-A    32   1.0  [0, 0]  262144   705
# 11               BUV 395-A    32   1.0  [0, 0]  262144   576
# 12               BUV 737-A    32   1.0  [0, 0]  262144   645
# 13                   APC-A    32   1.0  [0, 0]  262144   568
# 14                BV 421-A    32   1.0  [0, 0]  262144   507
# ...

# %%
type(tsample)
# Out:
# FlowCytometryTools.core.containers.FCMeasurement

# %%
type(tsample)
